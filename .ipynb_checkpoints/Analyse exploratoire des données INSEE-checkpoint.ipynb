# %% [markdown]
# ### Plan d'analyse :
# Objectif : questionner la rigueur statistique de l'indice de vulnérabilité utilisé dans les schémas de protection de l'enfance
# Méthode : isoler les indicateurs sur un département donné et étudier les relations entre variables
# Indicateurs à étudier :
# -  Nombre de jeunes de moins de 20 ans
# - Taux de jeunes dans la population
# - Niveaux de revenus ou taux de pauvreté
# - nombre de familles monoparentales
# - nombre de familles nombreuses
# - Indicateurs de logement : taille des logements, logements insalubres ?
#
# Dans un 2ème temps, essayer de trouver une relation entre nb de placements et indicateurs de vulnérabilité

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 1. Préparation des données

# %% [markdown]
# ### Import de la base cc evol struct pop

# %%
#Chargement du dataset
df_evolpop = pd.read_excel(r"C:\Users\thiba\Documents\Projets data\2023_indicateur INSEE\Bases_données_INSEE\base-cc-evol-struct-pop-2020.xlsx", sheet_name = "COM_2020")

# %%
df_evolpop1 = df_evolpop
df_evolpop1.head(5)
# Out:
#   Chiffres détaillés    -     Évolution et structure de la population  \
# 0                     France hors Mayotte - Communes
# 1  Mise en ligne le 27/06/2023       Géographie a...
# 2  ©Insee       Source(s) : Insee, Recensements d...
# 3                                  Code géographique
# 4                                             CODGEO
#
#   Unnamed: 1   Unnamed: 2            Unnamed: 3                  Unnamed: 4  \
# 0        NaN          NaN                   NaN                         NaN
# 1        NaN          NaN                   NaN                         NaN
# 2        NaN          NaN                   NaN                         NaN
# 3     Région  Département  Libellé géographique  Population en 2020 (princ)
# 4        REG          DEP                LIBGEO                     P20_POP
#
#                      Unnamed: 5                     Unnamed: 6  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3  Pop 0-14 ans en 2020 (princ)  Pop 15-29 ans en 2020 (princ)
# 4                   P20_POP0014                    P20_POP1529
#
#                       Unnamed: 7                     Unnamed: 8  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3  Pop 30-44 ans en 2020 (princ)  Pop 45-59 ans en 2020 (princ)
# 4                    P20_POP3044                    P20_POP4559
#
#                       Unnamed: 9  ...                           Unnamed: 98  \
# 0                            NaN  ...                                   NaN
# 1                            NaN  ...                                   NaN
# 2                            NaN  ...                                   NaN
# 3  Pop 60-74 ans en 2020 (princ)  ...  Pop 25-54 ans Autres en 2020 (compl)
# 4                    P20_POP6074  ...                       C20_POP2554_CS8
#
#                           Unnamed: 99  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3  Pop 55 ans ou plus en 2020 (compl)
# 4                          C20_POP55P
#
#                                         Unnamed: 100  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Pop 55 ans ou plus Agriculteurs exploitants en...
# 4                                     C20_POP55P_CS1
#
#                                         Unnamed: 101  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Pop 55 ans ou plus Artisans, Comm., Chefs entr...
# 4                                     C20_POP55P_CS2
#
#                                         Unnamed: 102  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Pop 55 ans ou plus Cadres, Prof. intel. sup. e...
# 4                                     C20_POP55P_CS3
#
#                                         Unnamed: 103  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Pop 55 ans ou plus Prof. intermédiaires en 202...
# 4                                     C20_POP55P_CS4
#
#                                   Unnamed: 104  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3  Pop 55 ans ou plus Employés en 2020 (compl)
# 4                               C20_POP55P_CS5
#
#                                   Unnamed: 105  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3  Pop 55 ans ou plus Ouvriers en 2020 (compl)
# 4                               C20_POP55P_CS6
#
#                                    Unnamed: 106  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3  Pop 55 ans ou plus Retraités en 2020 (compl)
# 4                                C20_POP55P_CS7
#
#                                 Unnamed: 107
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3  Pop 55 ans ou plus Autres en 2020 (compl)
# 4                             C20_POP55P_CS8
#
# [5 rows x 108 columns]

# %%
noms_champs = dict(zip(df_evolpop1.loc[4], df_evolpop1.loc[3]))
print(noms_champs)
# Out:
# {'CODGEO': 'Code géographique', 'REG': 'Région', 'DEP': 'Département', 'LIBGEO': 'Libellé géographique', 'P20_POP': 'Population en 2020 (princ)', 'P20_POP0014': 'Pop 0-14 ans en 2020 (princ)', 'P20_POP1529': 'Pop 15-29 ans en 2020 (princ)', 'P20_POP3044': 'Pop 30-44 ans en 2020 (princ)', 'P20_POP4559': 'Pop 45-59 ans en 2020 (princ)', 'P20_POP6074': 'Pop 60-74 ans en 2020 (princ)', 'P20_POP7589': 'Pop 75-89 ans en 2020 (princ)', 'P20_POP90P': 'Pop 90 ans ou plus en 2020 (princ)', 'P20_POPH': 'Pop Hommes en 2020 (princ)', 'P20_H0014': 'Pop Hommes 0-14 ans en 2020 (princ)', 'P20_H1529': 'Pop Hommes 15-29 ans en 2020 (princ)', 'P20_H3044': 'Pop Hommes 30-44 ans en 2020 (princ)', 'P20_H4559': 'Pop Hommes 45-59 ans en 2020 (princ)', 'P20_H6074': 'Pop Hommes 60-74 ans en 2020 (princ)', 'P20_H7589': 'Pop Hommes 75-89 ans en 2020 (princ)', 'P20_H90P': 'Pop Hommes 90 ans ou plus en 2020 (princ)', 'P20_H0019': 'Pop Hommes 0-19 ans en 2020  (princ)', 'P20_H2064': 'Pop Hommes 20-64 ans en 2020 (princ)', 'P20_H65P': 'Pop Hommes 65 ans ou plus en 2020 (princ)', 'P20_POPF': 'Pop Femmes en 2020 (princ)', 'P20_F0014': 'Pop Femmes 0-14 ans en 2020 (princ)', 'P20_F1529': 'Pop Femmes 15-29 ans en 2020 (princ)', 'P20_F3044': 'Pop Femmes 30-44 ans en 2020 (princ)', 'P20_F4559': 'Pop Femmes 45-59 ans en 2020 (princ)', 'P20_F6074': 'Pop Femmes 60-74 ans en 2020 (princ)', 'P20_F7589': 'Pop Femmes 75-89 ans en 2020 (princ)', 'P20_F90P': 'Pop Femmes 90 ans ou plus en 2020 (princ)', 'P20_F0019': 'Pop Femmes 0-19 ans en 2020 (princ)', 'P20_F2064': 'Pop Femmes 20-64 ans en 2020 (princ)', 'P20_F65P': 'Pop Femmes 65 ans ou plus en 2020 (princ)', 'P20_POP01P': 'Pop 1 an ou plus en 2020 localisée 1 an auparavant (princ)', 'P20_POP01P_IRAN1': 'Pop 1 an ou plus habitant 1 an avt même logt en 2020 (princ)', 'P20_POP01P_IRAN2': 'Pop 1 an ou plus habitant 1 an avt autre logt même commune en 2020 (princ)', 'P20_POP01P_IRAN3': 'Pop 1 an ou plus habitant 1 an avt autre commune même dépt en 2020 (princ)', 'P20_POP01P_IRAN4': 'Pop 1 an ou plus habitant 1 an avt autre dépt même région en 2020 (princ)', 'P20_POP01P_IRAN5': 'Pop 1 an ou plus habitant 1 an avt autre région métropole en 2020 (princ)', 'P20_POP01P_IRAN6': 'Pop 1 an ou plus habitant 1 an avt un Dom en 2020 (princ)', 'P20_POP01P_IRAN7': 'Pop 1 an ou plus habitant 1 an avt hors métro ou Dom en 2020 (princ)', 'P20_POP0114_IRAN2P': 'Pop 1-14 ans habitant 1 an avt autre logt en 2020 (princ)', 'P20_POP0114_IRAN2': 'Pop 1-14 ans habitant 1 an avt autre logt même commune en 2020 (princ)', 'P20_POP0114_IRAN3P': 'Pop 1-14 ans habitant 1 an avt autre commune en 2020 (princ)', 'P20_POP1524_IRAN2P': 'Pop 15-24 ans habitant 1 an avt autre logt en 2020 (princ)', 'P20_POP1524_IRAN2': 'Pop 15-24 ans habitant 1 an avt autre logt même commune en 2020 (princ)', 'P20_POP1524_IRAN3P': 'Pop 15-24 ans habitant 1 an avt autre commune en 2020 (princ)', 'P20_POP2554_IRAN2P': 'Pop 25-54 ans habitant 1 an avt autre logt en 2020 (princ)', 'P20_POP2554_IRAN2': 'Pop 25-54 ans habitant 1 an avt autre logt même commune en 2020 (princ)', 'P20_POP2554_IRAN3P': 'Pop 25-54 ans habitant 1 an avt autre commune en 2020 (princ)', 'P20_POP55P_IRAN2P': 'Pop 55 ans ou plus habitant 1 an avt autre logt en 2020 (princ)', 'P20_POP55P_IRAN2': 'Pop 55 ans ou plus habitant 1 an avt autre logt même commune en 2020 (princ)', 'P20_POP55P_IRAN3P': 'Pop 55 ans ou plus habitant 1 an avt autre commune en 2020 (princ)', 'C20_POP15P': 'Pop 15 ans ou plus en 2020 (compl)', 'C20_POP15P_CS1': 'Pop 15 ans ou plus Agriculteurs exploitants en 2020 (compl)', 'C20_POP15P_CS2': 'Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2020 (compl)', 'C20_POP15P_CS3': 'Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2020 (compl)', 'C20_POP15P_CS4': 'Pop 15 ans ou plus Prof. intermédiaires  en 2020 (compl)', 'C20_POP15P_CS5': 'Pop 15 ans ou plus Employés en 2020 (compl)', 'C20_POP15P_CS6': 'Pop 15 ans ou plus Ouvriers en 2020 (compl)', 'C20_POP15P_CS7': 'Pop 15 ans ou plus Retraités en ...

# %%
#On renomme les colonnes avec les vrais noms des champs INSEE
df_evolpop1.columns = df_evolpop.iloc[4]
#On supprime les lignes en trop
df_evolpop1 = df_evolpop1.drop([0, 1, 2, 3, 4], axis = 0)
df_evolpop1 = df_evolpop1.reset_index()

# %%
df_evolpop1.head()
df_evolpop1 = df_evolpop1.drop(["index"], axis = 1)
df_evolpop1.head()
# Out:
# 4 CODGEO REG DEP                   LIBGEO P20_POP  P20_POP0014 P20_POP1529  \
# 0  01001  84  01  L'Abergement-Clémenciat     806    155.30615    97.16938
# 1  01002  84  01    L'Abergement-de-Varey     262    57.242248   33.095709
# 2  01004  84  01        Ambérieu-en-Bugey   14288  2649.807321  3027.79416
# 3  01005  84  01      Ambérieux-en-Dombes    1782          353         273
# 4  01006  84  01                  Ambléon     113     9.912281   13.877193
#
# 4  P20_POP3044  P20_POP4559 P20_POP6074  ... C20_POP2554_CS8   C20_POP55P  \
# 0   148.761022   191.372049  143.616249  ...        9.386058   280.983168
# 1    56.756395    56.376187    38.18473  ...               0    87.696424
# 2  2691.337871  2427.065245   2169.6347  ...      564.147194  4270.361746
# 3          369          387         277  ...              20          515
# 4    19.824561    23.789474   37.666667  ...         4.95614    24.780702
#
# 4 C20_POP55P_CS1 C20_POP55P_CS2 C20_POP55P_CS3 C20_POP55P_CS4 C20_POP55P_CS5  \
# 0       4.692272      18.603513      18.603513      13.826181       9.300999
# 1              0              0       8.715094       8.442353              0
# 2        4.42397      90.430569     105.684499      258.15207     287.364692
# 3              0             35             25             50             25
# 4              0              0              0        4.95614              0
#
# 4 C20_POP55P_CS6 C20_POP55P_CS7 C20_POP55P_CS8
# 0      22.961578     183.694113       9.300999
# 1       4.493918      61.551141       4.493918
# 2     268.398693    2910.656689     345.250563
# 3             10            345             25
# 4              0      19.824561              0
#
# [5 rows x 108 columns]

# %%
#Infos du dataset : nombre de colonnes, stats
df_evolpop1.info()
#df_evolpop1.columns[4:108]
#df_evolpop1.columns[4:108] = df_evolpop1.columns[4:108].astype("float")
#df_evolpop1.iloc[:,4:108] = df_evolpop1.iloc[:,4:108].apply(pd.to_numeric)
df_evolpop1[df_evolpop1.columns[4:108]] = df_evolpop1[df_evolpop1.columns[4:108]].astype("float")
df_evolpop1.dtypes
#Learning : ILOC ne permet pas de changer les types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34928 entries, 0 to 34927
# Columns: 108 entries, CODGEO to C20_POP55P_CS8
# dtypes: object(108)
# memory usage: 28.8+ MB
# 4
# CODGEO             object
# REG                object
# DEP                object
# LIBGEO             object
# P20_POP           float64
#                    ...
# C20_POP55P_CS4    float64
# C20_POP55P_CS5    float64
# C20_POP55P_CS6    float64
# C20_POP55P_CS7    float64
# C20_POP55P_CS8    float64
# Length: 108, dtype: object

# %% [markdown]
# # 2. Exploration des données

# %%
#Maintenant que le df est prêt, premières explorations
df_reduit = df_evolpop1[["CODGEO","REG","DEP","LIBGEO","P20_POP","P20_POP0014","P20_POP1529","C20_POP15P_CS1","C20_POP15P_CS2","C20_POP15P_CS3","C20_POP15P_CS4","C20_POP15P_CS5","C20_POP15P_CS6","C20_POP15P_CS7", "C20_POP15P_CS8"]]
df = df_reduit[df_evolpop1["DEP"] == "13"]
# On enlève Marseille
i = df.loc[df["CODGEO"] == "13055"].index
i
df = df.drop(index = i)
df.loc[df["CODGEO"] == "13055"]
# Out:
# Empty DataFrame
# Columns: [CODGEO, REG, DEP, LIBGEO, P20_POP, P20_POP0014, P20_POP1529, C20_POP15P_CS1, C20_POP15P_CS2, C20_POP15P_CS3, C20_POP15P_CS4, C20_POP15P_CS5, C20_POP15P_CS6, C20_POP15P_CS7, C20_POP15P_CS8]
# Index: []

# %%
#distribution de la variable population en 2020
df.describe()
plt.figure(figsize = (10,7))
sns.histplot(x = "P20_POP", data = df)
plt.show()

# %%
df["CODGEO"].loc[(df.P20_POP == df.P20_POP.max())]
# Out:
# 4289    13001
# Name: CODGEO, dtype: object

# %%
sns.pairplot(data = df[["P20_POP", "C20_POP15P_CS1","C20_POP15P_CS2","C20_POP15P_CS3"]])

# %%
print(df.dtypes)
df_num = df.select_dtypes(include = ["int", "float"])
df_num = df_num.rename(noms_champs, axis = 1)
print(df_num.info())
# Out:
# 4
# CODGEO             object
# REG                object
# DEP                object
# LIBGEO             object
# P20_POP           float64
# P20_POP0014       float64
# P20_POP1529       float64
# C20_POP15P_CS1    float64
# C20_POP15P_CS2    float64
# C20_POP15P_CS3    float64
# C20_POP15P_CS4    float64
# C20_POP15P_CS5    float64
# C20_POP15P_CS6    float64
# C20_POP15P_CS7    float64
# C20_POP15P_CS8    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 4289 to 4407
# Data columns (total 11 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Population en 2020 (princ)                                       118 non-null    float64
#  1   Pop 0-14 ans en 2020 (princ)                                     118 non-null    float64
#  2   Pop 15-29 ans en 2020 (princ)                                    118 non-null    float64
#  3   Pop 15 ans ou plus Agriculteurs exploitants en 2020 (compl)      118 non-null    float64
#  4   Pop 15 ans ou plus Artisans, Comm., Chefs entr. en 2020 (compl)  118 non-null    float64
#  5   Pop 15 ans ou plus Cadres, Prof. intel. sup. en 2020 (compl)     118 non-null    float64
#  6   Pop 15 ans ou plus Prof. intermédiaires  en 2020 (compl)         118 non-null    float64
#  7   Pop 15 ans ou plus Employés en 2020 (compl)                      118 non-null    float64
#  8   Pop 15 ans ou plus Ouvriers en 2020 (compl)                      118 non-null    float64
#  9   Pop 15 ans ou plus Retraités en 2020 (compl)                     118 non-null    float64
#  10  Pop 15 ans ou plus Autres en 2020 (compl)                        118 non-null    float64
# dtypes: float64(11)
# memory usage: 15.1 KB
# None

# %%
coeff_corr = df_num.corr()
sns.heatmap(coeff_corr, annot = True, cmap = "flare")
# Out:
# <Axes: xlabel='4', ylabel='4'>
